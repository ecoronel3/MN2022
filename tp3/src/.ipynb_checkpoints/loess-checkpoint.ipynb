# %%
import numpy as np
from scipy import stats
import math
import numpy.linalg as linalg
import pandas as pd
from matplotlib import pyplot as plt
import sklearn as skl
from sklearn.preprocessing import PolynomialFeatures
import heapq

# %%
def tricubic(x):
    y = np.zeros_like(x)
    idx = (x >= 0) & (x <= 1)
    y[idx] = np.power(1.0 - np.power(np.abs(x[idx]), 3), 3)
    return y

# %%
def normalize(array):
    stds = array.std(axis=0)
    
    return (array- array.mean(axis=0))/stds

# %%
def get_max_dist(distances, q):
    mins = []
    for i in range(0, len(distances)):
        if len(mins) >= q:
            if mins[0] < -1*distances[i]:
                heapq.heapreplace(mins, -1*distances[i])
        else:
            heapq.heappush(mins, -1*distances[i])
    
    
    
    return mins[0]*-1

# %%
def get_weights(distances, max_dist):
    weights = tricubic(distances/max_dist)
    return np.diag(weights)

# %%
def loess(data, Y, f=0.1, fit=1, dist=2, normal=True):
    cant = len(Y)
    q = int(math.ceil(f*cant))
    if normal:
        data = normalize(data)
    
    y_ests = np.zeros_like(Y,dtype="float64")
    poly = PolynomialFeatures(fit)
    
    for i in range(0, cant):
        distances = linalg.norm(data - data[i], ord=dist, axis=1)
        max_dist = get_max_dist(distances, q)
        if i==0:
            print(max_dist)
        W = get_weights(distances, max_dist)
        b = Y
        A = poly.fit_transform(data)
            
        At = np.transpose(A)
        try:
            coeffs = linalg.solve(np.dot(At, np.dot(W, A)), np.dot(At, np.dot(W, b)))
        except:

            U, E, Vt = linalg.svd(np.dot(W, A))
            V = np.transpose(Vt)
            Ut = np.transpose(U)
            
            Et = np.zeros((np.shape(V)[1], np.shape(Ut)[0]))
            
            for j in range(0, len(E)):
                if E[j] != 0:
                    Et[j,j] = 1/E[j]
            
            MPInv = np.dot(V, np.dot(Et, Ut))
            coeffs = np.dot(MPInv, np.dot(W, b))
        
        y_est = np.dot(poly.fit_transform(data[i].reshape(1, -1)),coeffs)

        y_ests[i] = y_est
    
    return y_ests

# %%
data = pd.read_csv('../data/dataset.csv',usecols=['ozone', 'radiation', 'temperature', 'wind'])

# %%
x=data[['radiation', 'temperature', 'wind']].to_numpy()
y = data['ozone'].to_numpy()
estimates = loess(x, y, f=0.4, fit=1, dist=2, normal=False)
residuals = y - estimates
# Out:
# 59.685509129101014

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5))

res = stats.probplot(residuals, plot=plt, fit=False)

axs[1].get_lines()[0].set_marker('o')
axs[1].get_lines()[0].set_markeredgecolor('b')
axs[1].get_lines()[0].set_markerfacecolor('none')
axs[1].set_ylabel('Residuals')

abs_res= np.abs(residuals)
abs_res_est = loess(estimates.reshape((len(estimates),1)), abs_res, f=0.67, fit=1, dist=2, normal=False)

order_estimates = np.argsort(estimates)

axs[0].scatter(estimates, abs_res, edgecolor='b', facecolor='none')
axs[0].plot(estimates[order_estimates], abs_res_est[order_estimates], color='r')
axs[0].set_xlabel('Fitted Values')
axs[0].set_ylabel('Residuals')
# Out:
# 27.287702704174706
# Text(0, 0.5, 'Residuals')

# %%
cols = ['radiation','temperature','wind']

fig, axs = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    x = data[[cols[i]]].to_numpy()
    res_est = loess(x, residuals, f=0.67, fit=1, dist=2, normal=False)
    order = np.argsort(x.T[0])

    axs[i].scatter(x, residuals, edgecolor='b', facecolor='none')
    axs[i].plot(x[order], res_est[order], color='r')
    axs[i].set_xlabel(cols[i])
    axs[i].set_ylabel('Residuals')
# Out:
# 95.0
# 15.0
# 4.1

# %%
def loessRegressor(data, Y, regressed, f=0.1, fit=1, dist=2, normal=True):
    cant = len(regressed)
    q = int(math.ceil(f*len(Y)))
    if normal:
        data = normalize(data)
        regressed = normalize(regressed)
    
    y_ests = np.zeros(len(regressed),dtype="float64")
    poly = PolynomialFeatures(fit)
    L = np.zeros((len(regressed), len(Y)))
    
    
    for i in range(0, cant):
        distances = linalg.norm(data - regressed[i], ord=dist, axis=1)
        
        max_dist = get_max_dist(distances, q)
        W = get_weights(distances, max_dist)
        b = Y
        A = poly.fit_transform(data)
        
            
        At = np.transpose(A)
        try:
            #coeffs = linalg.solve(np.dot(At, np.dot(W, A)), np.dot(At, np.dot(W, b)))
            LsinX = linalg.inv(A.T@W@A)@A.T@W
            coeffs = LsinX@b
        except:

            U, E, Vt = linalg.svd(np.dot(W, A))
            V = np.transpose(Vt)
            Ut = np.transpose(U)
            
            Et = np.zeros((np.shape(V)[1], np.shape(Ut)[0]))
            
            for j in range(0, len(E)):
                if E[j] != 0:
                    Et[j,j] = 1/E[j]
            
            MPInv = np.dot(V, np.dot(Et, Ut))
            coeffs = np.dot(MPInv, np.dot(W, b))
        
        y_est = np.dot(poly.fit_transform(regressed[i].reshape(1, -1)),coeffs)
        
        
        
        L[i] = poly.fit_transform(regressed[i].reshape(1, -1))@LsinX

        y_ests[i] = y_est
    
    return y_ests, L

# %%
x=data[['radiation', 'temperature', 'wind']].to_numpy()

y = np.cbrt(data['ozone'].to_numpy())



size = 100
wind = 5.0
radiation = 290.0
temp = 62.0
temperature = np.column_stack((np.full(size,radiation), np.linspace(60,95,size,dtype="float64"), np.full(size,wind)))
print(temperature.shape)
print(x.shape)

estimates, L = loessRegressor(x, y, temperature, f=0.8, fit=2, dist=2, normal=False)

plt.plot(temperature[:,1], estimates)

estimatesBis= L@y

print(estimates - estimatesBis)
# Out:
# (100, 3)
# (111, 3)
# [ 3.55271368e-15 -9.76996262e-15 -1.50990331e-14 -1.06581410e-14
#   1.77635684e-15 -5.32907052e-15 -1.77635684e-15  7.10542736e-15
#  -5.32907052e-15 -1.24344979e-14 -2.30926389e-14  2.22044605e-14
#   6.21724894e-15 -2.93098879e-14  9.76996262e-15  3.55271368e-15
#   3.55271368e-15 -3.28626015e-14  1.15463195e-14  2.13162821e-14
#  -4.44089210e-15 -9.76996262e-15  1.33226763e-14  2.66453526e-15
#  -1.86517468e-14  8.88178420e-16 -6.21724894e-15  9.76996262e-15
#  -3.99680289e-14 -2.66453526e-14 -4.44089210e-15  5.32907052e-15
#  -9.76996262e-15  8.88178420e-16 -1.77635684e-15 -4.44089210e-15
#   1.24344979e-14 -1.95399252e-14  3.55271368e-15  3.55271368e-15
#  -2.93098879e-14  1.77635684e-14  3.55271368e-14  5.32907052e-15
#  -2.04281037e-14  1.77635684e-15 -3.81916720e-14  1.95399252e-14
#  -4.44089210e-15 -3.19744231e-14  1.33226763e-14  2.66453526e-15
#   8.88178420e-15  2.13162821e-14 -1.42108547e-14  2.39808173e-14
# ...

# %%
cols = ['radiation','ozone','temperature','wind']
fig, axs = plt.subplots(4,4,sharex='col', sharey='row', figsize=(15,15))
        
axs[0,0].set_ylabel(cols[0])
axs[3,3].set_xlabel(cols[3])
for i in range(0,4):
    for j in range(0,4):
        if i!=j:
            
            if(j==0):
                data.plot.scatter(x=cols[j], y=cols[i], ax=axs[i,j], subplots=True, sharey=True, 
                                  ylabel=cols[i], ylim=(data[cols[i]].min()-1, data[cols[i]].max()+1),
                                  c='none', edgecolor='b')
            else:
                data.plot.scatter(x=cols[j], y=cols[i], ax=axs[i,j], 
                          subplots=True, sharey=True, c='none', edgecolor='b')
                

axs[3,2].set_xticks([60,70,80,90])
axs[3,3].set_xticks([5,10,15,20])
